# %%
import ipywidgets as widgets
from IPython.display import display

a = widgets.IntSlider(value=5, min=0, max=10)

def f1(a):
    display(a)

def f2(a):
    display(a * 2)

out1 = widgets.interactive_output(f1, {'a': a})
out2 = widgets.interactive_output(f2, {'a': a})

display(a)
display(out1)
display(out2)
# Out:
# IntSlider(value=5, max=10)
# Output()
# Output()

# %% [markdown]
# # Hello

# %% [markdown]
# # World!

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 101)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="639.5999695014968">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…

# %%
def hide_code_in_slideshow():   
    from IPython import display
    import binascii
    import os
    uid = binascii.hexlify(os.urandom(8)).decode()    
    html = """<div id="%s"></div>
    <script type="text/javascript">
        $(function(){
            var p = $("#%s");
            if (p.length==0) return;
            while (!p.hasClass("cell")) {
                p=p.parent();
                if (p.prop("tagName") =="body") return;
            }
            var cell = p;
            cell.find(".input").addClass("hide-in-slideshow")
        });
    </script>""" % (uid, uid)
    display.display_html(html, raw=True)

# %%
hide_code_in_slideshow()

# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 101)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update);
# Out:
# <div id="f73564808bee11fc"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#f73564808bee11fc");
#             if (p.length==0) return;
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>
# <img src="data:image/png;base64,..." width="473.77777777777777">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…

# %%
##### import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
#plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-1.5, 1.5))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title('Sine Wave Signal')
    #return line,

anim = FuncAnimation(fig, animate, init_func=init,
                                   frames=200, interval=40, blit=True)

plt.tight_layout()
anim.save('sine_wave.gif', writer='imagemagick')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
import numpy
from numpy import pi


t, sample_rate, frequency, phase = numpy.linspace(0, 2, 1001), 10, 1, 0
signal = lambda t, f=1., phi=0: numpy.sin(2*pi*t*f-phi)

fig, ax = plt.subplots()
fig.set_size_inches(8,4)

#@interact(sample_rate=(1,25, 0.1), frequency=(-9,10, 0.1), phase=(-6, 6, 0.1))
def update(sample_rate=sample_rate, frequency=frequency, phase=0.):
    ax.cla()
    t_samples = numpy.arange(min(t), max(t), 1./sample_rate)
    x, x_sampled = signal(t, frequency, phase), signal(t_samples, frequency, phase)
    ax.plot(t, x, label='Original Signal')
    ax.stem(t_samples, x_sampled, linefmt='r', label='Sampled', use_line_collection=True)
    ax.plot(t_samples, x_sampled, '--k', label='Recovered')
    ax.legend(loc='lower left')
    fig.canvas.draw_idle()
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title('Sine Wave Signal')
    fig.tight_layout()

    
def animate(frame):
    phase = 2*pi*frame/200
    update(phase=phase)

anim = FuncAnimation(fig, animate, frames=200, interval=30, blit=True)

plt.tight_layout()
anim.save('sine_wave_sampled.gif', writer='imagemagick')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
# !ls
# Out:
#  1280px-LIGO_Hanford_aerial_05.jpg
#  GameStopStock.png
#  itsp
#  NASA-Satellite-sea-level-rise-observations.jpg
#  Overview.ipynb
#  probability_mass_function.png
#  probability_pdf_cdf.png
#  probability.png
#  probability_point.png
#  probability_regoin.png
#  probability_total.png
#  Section_1_figures.ipynb
# 'Section 1.ipynb'
# 'Section 2.ipynb'
#  sine_wave.gif
#  sine_wave_sampled.gif
#  Sunspot_Numbers.png
#  Sunspots_1302_Sep_2011_by_NASA.jpg
#  Theme_Classic.png
#  Theme_Dark.png
#  Untitled.ipynb
#  vector_addition.png
#  vector.png
#  vector_span.png

# %%
# !wget https://www.nasa.gov/sites/default/files/thumbnails/image/ns_gw_art.jpg
# Out:
# --2021-09-14 21:30:03--  https://www.nasa.gov/sites/default/files/thumbnails/image/ns_gw_art.jpg
# Resolving www.nasa.gov (www.nasa.gov)... 13.33.68.24, 13.33.68.51, 13.33.68.123, ...
# Connecting to www.nasa.gov (www.nasa.gov)|13.33.68.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1309046 (1.2M) [image/jpeg]
# Saving to: ‘ns_gw_art.jpg’
#
# ns_gw_art.jpg       100%[===================>]   1.25M  4.46MB/s    in 0.3s
#
# 2021-09-14 21:30:04 (4.46 MB/s) - ‘ns_gw_art.jpg’ saved [1309046/1309046]

# %%
ls
# Out:
#  1280px-LIGO_Hanford_aerial_05.jpg
#  GameStopStock.png
#  itsp/
#  NASA-Satellite-sea-level-rise-observations.jpg
#  ns_gw_art.jpg
#  Overview.ipynb
#  probability_mass_function.png
#  probability_pdf_cdf.png
#  probability.png
#  probability_point.png
#  probability_regoin.png
#  probability_total.png
#  Section_1_figures.ipynb
# 'Section 1.ipynb'
# 'Section 2.ipynb'
#  sine_wave.gif
#  sine_wave_sampled.gif
#  Sunspot_Numbers.png
#  Sunspots_1302_Sep_2011_by_NASA.jpg
#  Theme_Classic.png
#  Theme_Dark.png
#  Untitled.ipynb
#  vector_addition.png
#  vector.png
#  vector_span.png

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Bodensee_at_Lindau_-_DSC06962.JPG/1280px-Bodensee_at_Lindau_-_DSC06962.JPG
# Out:
# --2021-09-14 23:14:41--  https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Bodensee_at_Lindau_-_DSC06962.JPG/1280px-Bodensee_at_Lindau_-_DSC06962.JPG
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151813 (148K) [image/jpeg]
# Saving to: ‘1280px-Bodensee_at_Lindau_-_DSC06962.JPG.1’
#
# 1280px-Bodensee_at_ 100%[===================>] 148.25K  --.-KB/s    in 0.1s
#
# 2021-09-14 23:14:42 (1.38 MB/s) - ‘1280px-Bodensee_at_Lindau_-_DSC06962.JPG.1’ saved [151813/151813]

# %%
# !mv 1280px-Bodensee_at_Lindau_-_DSC06962.JPG duck_wake.jpg

# %%
# !wget https://d2pn8kiwq2w21t.cloudfront.net/images/imagesasteroid20121126asteroid20121114-640.width-640.jpg
# !mv imagesasteroid20121126asteroid20121114-640.width-640.jpg astro_sar_img.jpg
# Out:
# --2021-09-14 23:23:00--  https://d2pn8kiwq2w21t.cloudfront.net/images/imagesasteroid20121126asteroid20121114-640.width-640.jpg
# Resolving d2pn8kiwq2w21t.cloudfront.net (d2pn8kiwq2w21t.cloudfront.net)... 13.33.25.181, 13.33.25.134, 13.33.25.45, ...
# Connecting to d2pn8kiwq2w21t.cloudfront.net (d2pn8kiwq2w21t.cloudfront.net)|13.33.25.181|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39086 (38K) [image/jpeg]
# Saving to: ‘imagesasteroid20121126asteroid20121114-640.width-640.jpg’
#
# imagesasteroid20121 100%[===================>]  38.17K  --.-KB/s    in 0.04s
#
# 2021-09-14 23:23:00 (932 KB/s) - ‘imagesasteroid20121126asteroid20121114-640.width-640.jpg’ saved [39086/39086]

# %%
# !wget https://www.dropbox.com/s/v3rhot4xnf9z904/Scope.jpeg?dl=0
# Out:
# --2021-09-14 23:34:40--  https://www.dropbox.com/s/v3rhot4xnf9z904/Scope.jpeg?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/v3rhot4xnf9z904/Scope.jpeg [following]
# --2021-09-14 23:34:40--  https://www.dropbox.com/s/raw/v3rhot4xnf9z904/Scope.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucce92c4cacbf9c2c80195e9cd6b.dl.dropboxusercontent.com/cd/0/inline/BWOErcTzS76Y2GNQlI8vb8V71SU71B9u_0ta_-ux5rtVit2f61FcUpDn1mgQDJPyvTn0jFyTj2BNMCU9cwB9OI9JstRbI69bNVNedwAQsPDPyNzBCI_GdADSnjk-2LYvYa5WJauMKUGVmrDRqOezO6oK/file# [following]
# ...

# %%
# !mv 'Scope.jpeg?dl=0' Scope.jpeg

# %%
for i in range(1, 9):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Aliasing-folding_SVG.svg/1920px-Aliasing-folding_SVG.svg.png
# Out:
# --2021-09-15 20:05:29--  https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Aliasing-folding_SVG.svg/1920px-Aliasing-folding_SVG.svg.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193253 (189K) [image/png]
# Saving to: ‘1920px-Aliasing-folding_SVG.svg.png’
#
# 1920px-Aliasing-fol 100%[===================>] 188.72K  --.-KB/s    in 0.1s
#
# 2021-09-15 20:05:29 (1.34 MB/s) - ‘1920px-Aliasing-folding_SVG.svg.png’ saved [193253/193253]

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Dot_Product.svg/1280px-Dot_Product.svg.png
# Out:
# --2021-09-15 20:52:17--  https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Dot_Product.svg/1280px-Dot_Product.svg.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35101 (34K) [image/png]
# Saving to: ‘1280px-Dot_Product.svg.png’
#
# 1280px-Dot_Product. 100%[===================>]  34.28K  --.-KB/s    in 0.05s
#
# 2021-09-15 20:52:17 (651 KB/s) - ‘1280px-Dot_Product.svg.png’ saved [35101/35101]
